# %% [markdown]
# # Vision Transformer (ViT) for Image Classification [5 points]
# Use a Vision Transformer to solve the Cats and Dogs Dataset. You can use pre-defined ViT model or implement from scratch.
# Deploy the model and record a short video (~5 mins) on how it works.

# %% [markdown]
# ## Steps:

# %% [markdown]
# 1. Load and preprocess the dataset. This may include resizing images, normalizing pixel values, and splitting the dataset into training, validation, and testing sets.

# %%
import os
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import torch
import torch.nn as nn
import timm
import torch.optim as optim
from tqdm import tqdm

# %%
# !unzip PetImages.zip -d PetImages/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: PetImages/PetImages/Dog/7272.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7272.jpg
#   inflating: PetImages/PetImages/Dog/8141.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8141.jpg
#   inflating: PetImages/PetImages/Dog/1603.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1603.jpg
#   inflating: PetImages/PetImages/Dog/397.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._397.jpg
#   inflating: PetImages/PetImages/Dog/5465.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5465.jpg
#   inflating: PetImages/PetImages/Dog/3014.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3014.jpg
#   inflating: PetImages/PetImages/Dog/11553.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11553.jpg
#   inflating: PetImages/PetImages/Dog/10895.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10895.jpg
#   inflating: PetImages/PetImages/Dog/5471.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5471.jpg
#   inflating: PetImages/PetImages/Dog/10659.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10659.jpg
#   inflating: PetImages/PetImages/Dog/3000.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3000.jpg
#   inflating: PetImages/PetImages/Dog/11547.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11547.jpg
#   inflating: PetImages/PetImages/Dog/10881.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10881.jpg
#   inflating: PetImages/PetImages/Dog/7266.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7266.jpg
#   inflating: PetImages/PetImages/Dog/8155.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8155.jpg
#   inflating: PetImages/PetImages/Dog/383.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._383.jpg
#   inflating: PetImages/PetImages/Dog/1617.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1617.jpg
#   inflating: PetImages/PetImages/Dog/6178.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6178.jpg
#   inflating: PetImages/PetImages/Dog/1171.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1171.jpg
#   inflating: PetImages/PetImages/Dog/7500.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7500.jpg
#   inflating: PetImages/PetImages/Dog/8633.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8633.jpg
#   inflating: PetImages/PetImages/Dog/4009.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4009.jpg
#   inflating: PetImages/PetImages/Dog/3766.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3766.jpg
#   inflating: PetImages/PetImages/Dog/11221.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11221.jpg
#   inflating: PetImages/PetImages/Dog/2478.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2478.jpg
#   inflating: PetImages/PetImages/Dog/5317.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5317.jpg
#   inflating: PetImages/PetImages/Dog/9505.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9505.jpg
#   inflating: PetImages/PetImages/Dog/6636.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6636.jpg
#   inflating: PetImages/PetImages/Dog/1159.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1159.jpg
#   inflating: PetImages/PetImages/Dog/7528.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7528.jpg
#   inflating: PetImages/PetImages/Dog/4021.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4021.jpg
#   inflating: PetImages/PetImages/Dog/11209.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11209.jpg
#   inflating: PetImages/PetImages/Dog/10117.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10117.jpg
#   inflating: PetImages/PetImages/Dog/2450.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2450.jpg
#   inflating: PetImages/PetImages/Dog/3996.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3996.jpg
#   inflating: PetImages/PetImages/Dog/5459.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5459.jpg
#   inflating: PetImages/PetImages/Dog/10671.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10671.jpg
#   inflating: PetImages/PetImages/Dog/2336.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2336.jpg
#   inflating: PetImages/PetImages/Dog/3028.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3028.jpg
#   inflating: PetImages/PetImages/Dog/4747.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4747.jpg
#   inflating: PetImages/PetImages/Dog/12066.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12066.jpg
#   inflating: PetImages/PetImages/Dog/9263.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9263.jpg
#   inflating: PetImages/PetImages/Dog/6150.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6150.jpg
#   inflating: PetImages/PetImages/Dog/8169.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8169.jpg
#   inflating: PetImages/PetImages/Dog/12072.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12072.jpg
#   inflating: PetImages/PetImages/Dog/9277.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9277.jpg
#   inflating: PetImages/PetImages/Dog/6144.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6144.jpg
#   inflating: PetImages/PetImages/Dog/10665.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10665.jpg
#   inflating: PetImages/PetImages/Dog/2322.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2322.jpg
#   inflating: PetImages/PetImages/Dog/4753.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4753.jpg
#   inflating: PetImages/PetImages/Dog/4035.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4035.jpg
#   inflating: PetImages/PetImages/Dog/10103.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10103.jpg
#   inflating: PetImages/PetImages/Dog/2444.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2444.jpg
#   inflating: PetImages/PetImages/Dog/3982.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3982.jpg
#   inflating: PetImages/PetImages/Dog/9511.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9511.jpg
#   inflating: PetImages/PetImages/Dog/6622.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6622.jpg
#   inflating: PetImages/PetImages/Dog/8380.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8380.jpg
#   inflating: PetImages/PetImages/Dog/156.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._156.jpg
#   inflating: PetImages/PetImages/Dog/11792.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11792.jpg
#   inflating: PetImages/PetImages/Dog/2875.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2875.jpg
#   inflating: PetImages/PetImages/Dog/630.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._630.jpg
#   inflating: PetImages/PetImages/Dog/9920.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9920.jpg
#   inflating: PetImages/PetImages/Dog/624.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._624.jpg
#   inflating: PetImages/PetImages/Dog/7919.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7919.jpg
#   inflating: PetImages/PetImages/Dog/9934.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9934.jpg
#   inflating: PetImages/PetImages/Dog/2861.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2861.jpg
#   inflating: PetImages/PetImages/Dog/10498.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10498.jpg
#   inflating: PetImages/PetImages/Dog/5868.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5868.jpg
#   inflating: PetImages/PetImages/Dog/11786.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11786.jpg
#   inflating: PetImages/PetImages/Dog/8394.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8394.jpg
#   inflating: PetImages/PetImages/Dog/142.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._142.jpg
#   inflating: PetImages/PetImages/Dog/11976.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11976.jpg
#   inflating: PetImages/PetImages/Dog/5698.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5698.jpg
#   inflating: PetImages/PetImages/Dog/4586.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4586.jpg
#   inflating: PetImages/PetImages/Dog/5840.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5840.jpg
#   inflating: PetImages/PetImages/Dog/6391.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6391.jpg
#   inflating: PetImages/PetImages/Dog/7931.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7931.jpg
#   inflating: PetImages/PetImages/Dog/1398.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1398.jpg
#   inflating: PetImages/PetImages/Dog/94.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._94.jpg
#   inflating: PetImages/PetImages/Dog/2849.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2849.jpg
#   inflating: PetImages/PetImages/Dog/2691.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2691.jpg
#   inflating: PetImages/PetImages/Dog/2685.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2685.jpg
#   inflating: PetImages/PetImages/Dog/7925.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7925.jpg
#   inflating: PetImages/PetImages/Dog/618.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._618.jpg
#   inflating: PetImages/PetImages/Dog/80.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._80.jpg
#   inflating: PetImages/PetImages/Dog/9908.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9908.jpg
#   inflating: PetImages/PetImages/Dog/6385.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6385.jpg
#   inflating: PetImages/PetImages/Dog/11962.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11962.jpg
#   inflating: PetImages/PetImages/Dog/4592.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4592.jpg
#   inflating: PetImages/PetImages/Dog/5854.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5854.jpg
#   inflating: PetImages/PetImages/Dog/4579.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4579.jpg
#   inflating: PetImages/PetImages/Dog/11751.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11751.jpg
#   inflating: PetImages/PetImages/Dog/3216.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3216.jpg
#   inflating: PetImages/PetImages/Dog/2108.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2108.jpg
#   inflating: PetImages/PetImages/Dog/5667.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5667.jpg
#   inflating: PetImages/PetImages/Dog/11989.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11989.jpg
#   inflating: PetImages/PetImages/Dog/195.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._195.jpg
#   inflating: PetImages/PetImages/Dog/1401.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1401.jpg
#   inflating: PetImages/PetImages/Dog/12258.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12258.jpg
#   inflating: PetImages/PetImages/Dog/8343.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8343.jpg
#   inflating: PetImages/PetImages/Dog/7070.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7070.jpg
#   inflating: PetImages/PetImages/Dog/8425.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8425.jpg
#   inflating: PetImages/PetImages/Dog/7716.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7716.jpg
#   inflating: PetImages/PetImages/Dog/1367.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1367.jpg
#   inflating: PetImages/PetImages/Dog/6408.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6408.jpg
#   inflating: PetImages/PetImages/Dog/5101.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5101.jpg
#   inflating: PetImages/PetImages/Dog/10329.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10329.jpg
#   inflating: PetImages/PetImages/Dog/11037.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11037.jpg
#   inflating: PetImages/PetImages/Dog/3570.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3570.jpg
#   inflating: PetImages/PetImages/Dog/5115.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5115.jpg
#   inflating: PetImages/PetImages/Dog/11023.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11023.jpg
#   inflating: PetImages/PetImages/Dog/3564.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3564.jpg
#   inflating: PetImages/PetImages/Dog/8431.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8431.jpg
#   inflating: PetImages/PetImages/Dog/7702.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7702.jpg
#   inflating: PetImages/PetImages/Dog/1373.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1373.jpg
#   inflating: PetImages/PetImages/Dog/9049.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9049.jpg
#   inflating: PetImages/PetImages/Dog/1415.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1415.jpg
#   inflating: PetImages/PetImages/Dog/181.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._181.jpg
#   inflating: PetImages/PetImages/Dog/8357.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8357.jpg
#   inflating: PetImages/PetImages/Dog/7064.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7064.jpg
#   inflating: PetImages/PetImages/Dog/11745.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11745.jpg
#   inflating: PetImages/PetImages/Dog/3202.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3202.jpg
#   inflating: PetImages/PetImages/Dog/5673.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5673.jpg
#   inflating: PetImages/PetImages/Dog/6352.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6352.jpg
#   inflating: PetImages/PetImages/Dog/9061.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9061.jpg
#   inflating: PetImages/PetImages/Dog/12264.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12264.jpg
#   inflating: PetImages/PetImages/Dog/4545.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4545.jpg
#   inflating: PetImages/PetImages/Dog/5883.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5883.jpg
#   inflating: PetImages/PetImages/Dog/5.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5.jpg
#   inflating: PetImages/PetImages/Dog/2134.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2134.jpg
#   inflating: PetImages/PetImages/Dog/10473.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10473.jpg
#   inflating: PetImages/PetImages/Dog/2652.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2652.jpg
#   inflating: PetImages/PetImages/Dog/10315.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10315.jpg
#   inflating: PetImages/PetImages/Dog/4223.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4223.jpg
#   inflating: PetImages/PetImages/Dog/817.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._817.jpg
#   inflating: PetImages/PetImages/Dog/8419.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8419.jpg
#   inflating: PetImages/PetImages/Dog/57.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._57.jpg
#   inflating: PetImages/PetImages/Dog/6434.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6434.jpg
#   inflating: PetImages/PetImages/Dog/9707.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9707.jpg
#   inflating: PetImages/PetImages/Dog/803.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._803.jpg
#   inflating: PetImages/PetImages/Dog/6420.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6420.jpg
#   inflating: PetImages/PetImages/Dog/43.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._43.jpg
#   inflating: PetImages/PetImages/Dog/9713.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9713.jpg
#   inflating: PetImages/PetImages/Dog/5129.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5129.jpg
#   inflating: PetImages/PetImages/Dog/2646.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2646.jpg
#   inflating: PetImages/PetImages/Dog/10301.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10301.jpg
#   inflating: PetImages/PetImages/Dog/3558.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3558.jpg
#   inflating: PetImages/PetImages/Dog/4237.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4237.jpg
#   inflating: PetImages/PetImages/Dog/4551.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4551.jpg
#   inflating: PetImages/PetImages/Dog/11779.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11779.jpg
#   inflating: PetImages/PetImages/Dog/5897.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5897.jpg
#   inflating: PetImages/PetImages/Dog/2120.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2120.jpg
#   inflating: PetImages/PetImages/Dog/10467.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10467.jpg
#   inflating: PetImages/PetImages/Dog/6346.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6346.jpg
#   inflating: PetImages/PetImages/Dog/9075.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9075.jpg
#   inflating: PetImages/PetImages/Dog/1429.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1429.jpg
#   inflating: PetImages/PetImages/Dog/12270.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12270.jpg
#   inflating: PetImages/PetImages/Dog/7058.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7058.jpg
#   inflating: PetImages/PetImages/Dog/6436.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6436.jpg
#   inflating: PetImages/PetImages/Dog/55.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._55.jpg
#   inflating: PetImages/PetImages/Dog/9705.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9705.jpg
#   inflating: PetImages/PetImages/Dog/1359.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1359.jpg
#   inflating: PetImages/PetImages/Dog/7728.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7728.jpg
#   inflating: PetImages/PetImages/Dog/815.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._815.jpg
#   inflating: PetImages/PetImages/Dog/2888.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2888.jpg
#   inflating: PetImages/PetImages/Dog/4221.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4221.jpg
#   inflating: PetImages/PetImages/Dog/11009.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11009.jpg
#   inflating: PetImages/PetImages/Dog/2650.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2650.jpg
#   inflating: PetImages/PetImages/Dog/10317.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10317.jpg
#   inflating: PetImages/PetImages/Dog/5659.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5659.jpg
#   inflating: PetImages/PetImages/Dog/2136.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2136.jpg
#   inflating: PetImages/PetImages/Dog/10471.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10471.jpg
#   inflating: PetImages/PetImages/Dog/3228.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3228.jpg
#   inflating: PetImages/PetImages/Dog/7.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7.jpg
#   inflating: PetImages/PetImages/Dog/5881.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5881.jpg
#   inflating: PetImages/PetImages/Dog/4547.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4547.jpg
#   inflating: PetImages/PetImages/Dog/12266.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12266.jpg
#   inflating: PetImages/PetImages/Dog/6350.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6350.jpg
#   inflating: PetImages/PetImages/Dog/9063.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9063.jpg
#   inflating: PetImages/PetImages/Dog/8369.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8369.jpg
#   inflating: PetImages/PetImages/Dog/12272.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12272.jpg
#   inflating: PetImages/PetImages/Dog/6344.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6344.jpg
#   inflating: PetImages/PetImages/Dog/9077.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9077.jpg
#   inflating: PetImages/PetImages/Dog/2122.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2122.jpg
#   inflating: PetImages/PetImages/Dog/10465.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10465.jpg
#   inflating: PetImages/PetImages/Dog/5895.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5895.jpg
#   inflating: PetImages/PetImages/Dog/4553.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4553.jpg
#   inflating: PetImages/PetImages/Dog/4235.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4235.jpg
#   inflating: PetImages/PetImages/Dog/2644.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2644.jpg
#   inflating: PetImages/PetImages/Dog/10303.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10303.jpg
#   inflating: PetImages/PetImages/Dog/41.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._41.jpg
#   inflating: PetImages/PetImages/Dog/6422.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6422.jpg
#   inflating: PetImages/PetImages/Dog/9711.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9711.jpg
#   inflating: PetImages/PetImages/Dog/801.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._801.jpg
#   inflating: PetImages/PetImages/Dog/11035.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11035.jpg
#   inflating: PetImages/PetImages/Dog/3572.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3572.jpg
#   inflating: PetImages/PetImages/Dog/5103.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5103.jpg
#   inflating: PetImages/PetImages/Dog/9739.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9739.jpg
#   inflating: PetImages/PetImages/Dog/69.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._69.jpg
#   inflating: PetImages/PetImages/Dog/1365.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1365.jpg
#   inflating: PetImages/PetImages/Dog/8427.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8427.jpg
#   inflating: PetImages/PetImages/Dog/829.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._829.jpg
#   inflating: PetImages/PetImages/Dog/7714.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7714.jpg
#   inflating: PetImages/PetImages/Dog/8341.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8341.jpg
#   inflating: PetImages/PetImages/Dog/7072.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7072.jpg
#   inflating: PetImages/PetImages/Dog/1403.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1403.jpg
#   inflating: PetImages/PetImages/Dog/197.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._197.jpg
#   inflating: PetImages/PetImages/Dog/5665.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5665.jpg
#   inflating: PetImages/PetImages/Dog/11753.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11753.jpg
#   inflating: PetImages/PetImages/Dog/3214.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3214.jpg
#   inflating: PetImages/PetImages/Dog/5671.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5671.jpg
#   inflating: PetImages/PetImages/Dog/10459.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10459.jpg
#   inflating: PetImages/PetImages/Dog/11747.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11747.jpg
#   inflating: PetImages/PetImages/Dog/3200.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3200.jpg
#   inflating: PetImages/PetImages/Dog/8355.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8355.jpg
#   inflating: PetImages/PetImages/Dog/7066.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7066.jpg
#   inflating: PetImages/PetImages/Dog/183.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._183.jpg
#   inflating: PetImages/PetImages/Dog/1417.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1417.jpg
#   inflating: PetImages/PetImages/Dog/6378.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6378.jpg
#   inflating: PetImages/PetImages/Dog/1371.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1371.jpg
#   inflating: PetImages/PetImages/Dog/8433.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8433.jpg
#   inflating: PetImages/PetImages/Dog/7700.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7700.jpg
#   inflating: PetImages/PetImages/Dog/4209.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4209.jpg
#   inflating: PetImages/PetImages/Dog/11021.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11021.jpg
#   inflating: PetImages/PetImages/Dog/3566.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3566.jpg
#   inflating: PetImages/PetImages/Dog/2678.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2678.jpg
#   inflating: PetImages/PetImages/Dog/5117.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5117.jpg
#   inflating: PetImages/PetImages/Dog/2693.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2693.jpg
#   inflating: PetImages/PetImages/Dog/96.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._96.jpg
#   inflating: PetImages/PetImages/Dog/7933.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7933.jpg
#   inflating: PetImages/PetImages/Dog/168.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._168.jpg
#   inflating: PetImages/PetImages/Dog/6393.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6393.jpg
#   inflating: PetImages/PetImages/Dog/5842.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5842.jpg
#   inflating: PetImages/PetImages/Dog/4584.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4584.jpg
#   inflating: PetImages/PetImages/Dog/11974.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11974.jpg
#   inflating: PetImages/PetImages/Dog/5856.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5856.jpg
#   inflating: PetImages/PetImages/Dog/4590.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4590.jpg
#   inflating: PetImages/PetImages/Dog/11960.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11960.jpg
#   inflating: PetImages/PetImages/Dog/6387.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6387.jpg
#   inflating: PetImages/PetImages/Dog/7099.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7099.jpg
#   inflating: PetImages/PetImages/Dog/82.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._82.jpg
#   inflating: PetImages/PetImages/Dog/7927.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7927.jpg
#   inflating: PetImages/PetImages/Dog/2687.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2687.jpg
#   inflating: PetImages/PetImages/Dog/3599.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3599.jpg
#   inflating: PetImages/PetImages/Dog/9922.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9922.jpg
#   inflating: PetImages/PetImages/Dog/632.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._632.jpg
#   inflating: PetImages/PetImages/Dog/2877.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2877.jpg
#   inflating: PetImages/PetImages/Dog/11790.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11790.jpg
#   inflating: PetImages/PetImages/Dog/11948.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11948.jpg
#   inflating: PetImages/PetImages/Dog/154.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._154.jpg
#   inflating: PetImages/PetImages/Dog/8382.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8382.jpg
#   inflating: PetImages/PetImages/Dog/12299.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12299.jpg
#   inflating: PetImages/PetImages/Dog/140.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._140.jpg
#   inflating: PetImages/PetImages/Dog/9088.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9088.jpg
#   inflating: PetImages/PetImages/Dog/8396.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8396.jpg
#   inflating: PetImages/PetImages/Dog/11784.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11784.jpg
#   inflating: PetImages/PetImages/Dog/2863.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2863.jpg
#   inflating: PetImages/PetImages/Dog/9936.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9936.jpg
#   inflating: PetImages/PetImages/Dog/626.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._626.jpg
#   inflating: PetImages/PetImages/Dog/9261.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9261.jpg
#   inflating: PetImages/PetImages/Dog/6152.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6152.jpg
#   inflating: PetImages/PetImages/Dog/12064.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12064.jpg
#   inflating: PetImages/PetImages/Dog/4745.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4745.jpg
#   inflating: PetImages/PetImages/Dog/10673.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10673.jpg
#   inflating: PetImages/PetImages/Dog/2334.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2334.jpg
#   inflating: PetImages/PetImages/Dog/3994.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3994.jpg
#   inflating: PetImages/PetImages/Dog/10115.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10115.jpg
#   inflating: PetImages/PetImages/Dog/2452.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2452.jpg
#   inflating: PetImages/PetImages/Dog/4023.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4023.jpg
#   inflating: PetImages/PetImages/Dog/8619.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8619.jpg
#   inflating: PetImages/PetImages/Dog/9507.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9507.jpg
#   inflating: PetImages/PetImages/Dog/6634.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6634.jpg
#   inflating: PetImages/PetImages/Dog/9513.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9513.jpg
#   inflating: PetImages/PetImages/Dog/6620.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6620.jpg
#   inflating: PetImages/PetImages/Dog/5329.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5329.jpg
#   inflating: PetImages/PetImages/Dog/3980.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3980.jpg
#   inflating: PetImages/PetImages/Dog/10101.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10101.jpg
#   inflating: PetImages/PetImages/Dog/2446.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2446.jpg
#   inflating: PetImages/PetImages/Dog/3758.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3758.jpg
#   inflating: PetImages/PetImages/Dog/4037.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4037.jpg
#   inflating: PetImages/PetImages/Dog/4751.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4751.jpg
#   inflating: PetImages/PetImages/Dog/11579.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11579.jpg
#   inflating: PetImages/PetImages/Dog/4989.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4989.jpg
#   inflating: PetImages/PetImages/Dog/10667.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10667.jpg
#   inflating: PetImages/PetImages/Dog/2320.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2320.jpg
#   inflating: PetImages/PetImages/Dog/9275.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9275.jpg
#   inflating: PetImages/PetImages/Dog/6146.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6146.jpg
#   inflating: PetImages/PetImages/Dog/1629.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1629.jpg
#   inflating: PetImages/PetImages/Dog/12070.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12070.jpg
#   inflating: PetImages/PetImages/Dog/7258.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7258.jpg
#   inflating: PetImages/PetImages/Dog/10897.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10897.jpg
#   inflating: PetImages/PetImages/Dog/4779.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4779.jpg
#   inflating: PetImages/PetImages/Dog/3016.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3016.jpg
#   inflating: PetImages/PetImages/Dog/11551.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11551.jpg
#   inflating: PetImages/PetImages/Dog/2308.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2308.jpg
#   inflating: PetImages/PetImages/Dog/5467.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5467.jpg
#   inflating: PetImages/PetImages/Dog/395.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._395.jpg
#   inflating: PetImages/PetImages/Dog/1601.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1601.jpg
#   inflating: PetImages/PetImages/Dog/12058.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12058.jpg
#   inflating: PetImages/PetImages/Dog/7270.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7270.jpg
#   inflating: PetImages/PetImages/Dog/8143.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8143.jpg
#   inflating: PetImages/PetImages/Dog/7516.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7516.jpg
#   inflating: PetImages/PetImages/Dog/8625.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8625.jpg
#   inflating: PetImages/PetImages/Dog/1167.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1167.jpg
#   inflating: PetImages/PetImages/Dog/6608.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6608.jpg
#   inflating: PetImages/PetImages/Dog/5301.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5301.jpg
#   inflating: PetImages/PetImages/Dog/10129.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10129.jpg
#   inflating: PetImages/PetImages/Dog/3770.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3770.jpg
#   inflating: PetImages/PetImages/Dog/11237.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11237.jpg
#   inflating: PetImages/PetImages/Dog/5315.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5315.jpg
#   inflating: PetImages/PetImages/Dog/3764.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3764.jpg
#   inflating: PetImages/PetImages/Dog/11223.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11223.jpg
#   inflating: PetImages/PetImages/Dog/7502.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7502.jpg
#   inflating: PetImages/PetImages/Dog/8631.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8631.jpg
#   inflating: PetImages/PetImages/Dog/1173.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1173.jpg
#   inflating: PetImages/PetImages/Dog/9249.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9249.jpg
#   inflating: PetImages/PetImages/Dog/1615.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1615.jpg
#   inflating: PetImages/PetImages/Dog/381.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._381.jpg
#   inflating: PetImages/PetImages/Dog/7264.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7264.jpg
#   inflating: PetImages/PetImages/Dog/8157.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8157.jpg
#   inflating: PetImages/PetImages/Dog/10883.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10883.jpg
#   inflating: PetImages/PetImages/Dog/3002.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3002.jpg
#   inflating: PetImages/PetImages/Dog/11545.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11545.jpg
#   inflating: PetImages/PetImages/Dog/5473.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5473.jpg
#   inflating: PetImages/PetImages/Dog/5498.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5498.jpg
#   inflating: PetImages/PetImages/Dog/4786.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4786.jpg
#   inflating: PetImages/PetImages/Dog/10868.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10868.jpg
#   inflating: PetImages/PetImages/Dog/1826.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1826.jpg
#   inflating: PetImages/PetImages/Dog/6191.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6191.jpg
#   inflating: PetImages/PetImages/Dog/8802.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8802.jpg
#   inflating: PetImages/PetImages/Dog/1198.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1198.jpg
#   inflating: PetImages/PetImages/Dog/3957.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3957.jpg
#   inflating: PetImages/PetImages/Dog/2491.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2491.jpg
#   inflating: PetImages/PetImages/Dog/3943.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3943.jpg
#   inflating: PetImages/PetImages/Dog/2485.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2485.jpg
#   inflating: PetImages/PetImages/Dog/418.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._418.jpg
#   inflating: PetImages/PetImages/Dog/8816.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8816.jpg
#   inflating: PetImages/PetImages/Dog/1832.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1832.jpg
#   inflating: PetImages/PetImages/Dog/6185.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6185.jpg
#   inflating: PetImages/PetImages/Dog/4792.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4792.jpg
#   inflating: PetImages/PetImages/Dog/8180.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8180.jpg
#   inflating: PetImages/PetImages/Dog/356.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._356.jpg
#   inflating: PetImages/PetImages/Dog/4962.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4962.jpg
#   inflating: PetImages/PetImages/Dog/10854.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10854.jpg
#   inflating: PetImages/PetImages/Dog/11592.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11592.jpg
#   inflating: PetImages/PetImages/Dog/430.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._430.jpg
#   inflating: PetImages/PetImages/Dog/6813.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6813.jpg
#   inflating: PetImages/PetImages/Dog/424.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._424.jpg
#   inflating: PetImages/PetImages/Dog/6807.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6807.jpg
#   inflating: PetImages/PetImages/Dog/10698.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10698.jpg
#   inflating: PetImages/PetImages/Dog/4976.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4976.jpg
#   inflating: PetImages/PetImages/Dog/10840.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10840.jpg
#   inflating: PetImages/PetImages/Dog/11586.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11586.jpg
#   inflating: PetImages/PetImages/Dog/8194.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8194.jpg
#   inflating: PetImages/PetImages/Dog/342.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._342.jpg
#   inflating: PetImages/PetImages/Dog/1991.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1991.jpg
#   inflating: PetImages/PetImages/Dog/7338.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7338.jpg
#   inflating: PetImages/PetImages/Dog/12110.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12110.jpg
#   inflating: PetImages/PetImages/Dog/1749.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1749.jpg
#   inflating: PetImages/PetImages/Dog/9315.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9315.jpg
#   inflating: PetImages/PetImages/Dog/6026.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6026.jpg
#   inflating: PetImages/PetImages/Dog/10707.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10707.jpg
#   inflating: PetImages/PetImages/Dog/2240.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2240.jpg
#   inflating: PetImages/PetImages/Dog/11419.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11419.jpg
#   inflating: PetImages/PetImages/Dog/4631.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4631.jpg
#   inflating: PetImages/PetImages/Dog/4157.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4157.jpg
#   inflating: PetImages/PetImages/Dog/3638.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3638.jpg
#   inflating: PetImages/PetImages/Dog/10061.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10061.jpg
#   inflating: PetImages/PetImages/Dog/2526.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2526.jpg
#   inflating: PetImages/PetImages/Dog/5249.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5249.jpg
#   inflating: PetImages/PetImages/Dog/9473.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9473.jpg
#   inflating: PetImages/PetImages/Dog/6740.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6740.jpg
#   inflating: PetImages/PetImages/Dog/6998.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6998.jpg
#   inflating: PetImages/PetImages/Dog/9467.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9467.jpg
#   inflating: PetImages/PetImages/Dog/6754.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6754.jpg
#   inflating: PetImages/PetImages/Dog/8779.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8779.jpg
#   inflating: PetImages/PetImages/Dog/4143.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4143.jpg
#   inflating: PetImages/PetImages/Dog/10075.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10075.jpg
#   inflating: PetImages/PetImages/Dog/2532.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2532.jpg
#   inflating: PetImages/PetImages/Dog/10713.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10713.jpg
#   inflating: PetImages/PetImages/Dog/2254.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2254.jpg
#   inflating: PetImages/PetImages/Dog/4625.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4625.jpg
#   inflating: PetImages/PetImages/Dog/1985.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1985.jpg
#   inflating: PetImages/PetImages/Dog/12104.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12104.jpg
#   inflating: PetImages/PetImages/Dog/9301.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9301.jpg
#   inflating: PetImages/PetImages/Dog/6032.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6032.jpg
#   inflating: PetImages/PetImages/Dog/5513.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5513.jpg
#   inflating: PetImages/PetImages/Dog/3162.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3162.jpg
#   inflating: PetImages/PetImages/Dog/11425.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11425.jpg
#   inflating: PetImages/PetImages/Dog/7304.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7304.jpg
#   inflating: PetImages/PetImages/Dog/8037.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8037.jpg
#   inflating: PetImages/PetImages/Dog/1775.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1775.jpg
#   inflating: PetImages/PetImages/Dog/9329.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9329.jpg
#   inflating: PetImages/PetImages/Dog/8989.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8989.jpg
#   inflating: PetImages/PetImages/Dog/587.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._587.jpg
#   inflating: PetImages/PetImages/Dog/1013.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1013.jpg
#   inflating: PetImages/PetImages/Dog/7462.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7462.jpg
#   inflating: PetImages/PetImages/Dog/8751.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8751.jpg
#   inflating: PetImages/PetImages/Dog/3604.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3604.jpg
#   inflating: PetImages/PetImages/Dog/11343.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11343.jpg
#   inflating: PetImages/PetImages/Dog/5275.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5275.jpg
#   inflating: PetImages/PetImages/Dog/3610.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3610.jpg
#   inflating: PetImages/PetImages/Dog/11357.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11357.jpg
#   inflating: PetImages/PetImages/Dog/10049.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10049.jpg
#   inflating: PetImages/PetImages/Dog/5261.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5261.jpg
#   inflating: PetImages/PetImages/Dog/6768.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6768.jpg
#   inflating: PetImages/PetImages/Dog/1007.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1007.jpg
#   inflating: PetImages/PetImages/Dog/593.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._593.jpg
#   inflating: PetImages/PetImages/Dog/7476.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7476.jpg
#   inflating: PetImages/PetImages/Dog/8745.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8745.jpg
#   inflating: PetImages/PetImages/Dog/7310.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7310.jpg
#   inflating: PetImages/PetImages/Dog/8023.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8023.jpg
#   inflating: PetImages/PetImages/Dog/12138.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12138.jpg
#   inflating: PetImages/PetImages/Dog/1761.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1761.jpg
#   inflating: PetImages/PetImages/Dog/5507.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5507.jpg
#   inflating: PetImages/PetImages/Dog/2268.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2268.jpg
#   inflating: PetImages/PetImages/Dog/3176.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3176.jpg
#   inflating: PetImages/PetImages/Dog/11431.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11431.jpg
#   inflating: PetImages/PetImages/Dog/4619.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4619.jpg
#   inflating: PetImages/PetImages/Dog/2283.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2283.jpg
#   inflating: PetImages/PetImages/Dog/1952.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1952.jpg
#   inflating: PetImages/PetImages/Dog/6783.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6783.jpg
#   inflating: PetImages/PetImages/Dog/578.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._578.jpg
#   inflating: PetImages/PetImages/Dog/8976.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8976.jpg
#   inflating: PetImages/PetImages/Dog/3823.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3823.jpg
#   inflating: PetImages/PetImages/Dog/4194.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4194.jpg
#   inflating: PetImages/PetImages/Dog/3837.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3837.jpg
#   inflating: PetImages/PetImages/Dog/4180.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4180.jpg
#   inflating: PetImages/PetImages/Dog/7489.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7489.jpg
#   inflating: PetImages/PetImages/Dog/6797.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6797.jpg
#   inflating: PetImages/PetImages/Dog/8962.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8962.jpg
#   inflating: PetImages/PetImages/Dog/1946.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1946.jpg
#   inflating: PetImages/PetImages/Dog/3189.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3189.jpg
#   inflating: PetImages/PetImages/Dog/10908.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10908.jpg
#   inflating: PetImages/PetImages/Dog/2297.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2297.jpg
#   inflating: PetImages/PetImages/Dog/222.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._222.jpg
#   inflating: PetImages/PetImages/Dog/10920.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10920.jpg
#   inflating: PetImages/PetImages/Dog/4816.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4816.jpg
#   inflating: PetImages/PetImages/Dog/11380.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11380.jpg
#   inflating: PetImages/PetImages/Dog/6967.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6967.jpg
#   inflating: PetImages/PetImages/Dog/8792.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8792.jpg
#   inflating: PetImages/PetImages/Dog/544.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._544.jpg
#   inflating: PetImages/PetImages/Dog/6973.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6973.jpg
#   inflating: PetImages/PetImages/Dog/8786.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8786.jpg
#   inflating: PetImages/PetImages/Dog/9498.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9498.jpg
#   inflating: PetImages/PetImages/Dog/550.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._550.jpg
#   inflating: PetImages/PetImages/Dog/11394.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11394.jpg
#   inflating: PetImages/PetImages/Dog/10934.jpg
# ...
#   inflating: PetImages/PetImages/Dog/10106.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10106.jpg
#   inflating: PetImages/PetImages/Dog/2441.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2441.jpg
#   inflating: PetImages/PetImages/Dog/1148.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1148.jpg
#   inflating: PetImages/PetImages/Dog/9514.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9514.jpg
#   inflating: PetImages/PetImages/Dog/6627.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6627.jpg
#   inflating: PetImages/PetImages/Dog/7539.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7539.jpg
#   inflating: PetImages/PetImages/Dog/12077.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12077.jpg
#   inflating: PetImages/PetImages/Dog/9272.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9272.jpg
#   inflating: PetImages/PetImages/Dog/6141.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6141.jpg
#   inflating: PetImages/PetImages/Dog/10660.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10660.jpg
#   inflating: PetImages/PetImages/Dog/2327.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2327.jpg
#   inflating: PetImages/PetImages/Dog/5448.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5448.jpg
#   inflating: PetImages/PetImages/Dog/4756.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4756.jpg
#   inflating: PetImages/PetImages/Dog/3039.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3039.jpg
#   inflating: PetImages/PetImages/Dog/7277.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7277.jpg
#   inflating: PetImages/PetImages/Dog/8144.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8144.jpg
#   inflating: PetImages/PetImages/Dog/6169.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6169.jpg
#   inflating: PetImages/PetImages/Dog/1606.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1606.jpg
#   inflating: PetImages/PetImages/Dog/392.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._392.jpg
#   inflating: PetImages/PetImages/Dog/10648.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10648.jpg
#   inflating: PetImages/PetImages/Dog/5460.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5460.jpg
#   inflating: PetImages/PetImages/Dog/10890.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10890.jpg
#   inflating: PetImages/PetImages/Dog/3011.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3011.jpg
#   inflating: PetImages/PetImages/Dog/11556.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11556.jpg
#   inflating: PetImages/PetImages/Dog/3777.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3777.jpg
#   inflating: PetImages/PetImages/Dog/11230.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11230.jpg
#   inflating: PetImages/PetImages/Dog/4018.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4018.jpg
#   inflating: PetImages/PetImages/Dog/5306.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5306.jpg
#   inflating: PetImages/PetImages/Dog/2469.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2469.jpg
#   inflating: PetImages/PetImages/Dog/1160.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1160.jpg
#   inflating: PetImages/PetImages/Dog/7511.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7511.jpg
#   inflating: PetImages/PetImages/Dog/8622.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8622.jpg
#   inflating: PetImages/PetImages/Dog/1174.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1174.jpg
#   inflating: PetImages/PetImages/Dog/9528.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9528.jpg
#   inflating: PetImages/PetImages/Dog/7505.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7505.jpg
#   inflating: PetImages/PetImages/Dog/8636.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8636.jpg
#   inflating: PetImages/PetImages/Dog/3763.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3763.jpg
#   inflating: PetImages/PetImages/Dog/11224.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11224.jpg
#   inflating: PetImages/PetImages/Dog/5312.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5312.jpg
#   inflating: PetImages/PetImages/Dog/5474.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5474.jpg
#   inflating: PetImages/PetImages/Dog/10884.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10884.jpg
#   inflating: PetImages/PetImages/Dog/3005.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3005.jpg
#   inflating: PetImages/PetImages/Dog/11542.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11542.jpg
#   inflating: PetImages/PetImages/Dog/7263.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7263.jpg
#   inflating: PetImages/PetImages/Dog/8150.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8150.jpg
#   inflating: PetImages/PetImages/Dog/386.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._386.jpg
#   inflating: PetImages/PetImages/Dog/1612.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1612.jpg
#   inflating: PetImages/PetImages/Dog/91.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._91.jpg
#   inflating: PetImages/PetImages/Dog/7934.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7934.jpg
#   inflating: PetImages/PetImages/Dog/609.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._609.jpg
#   inflating: PetImages/PetImages/Dog/9919.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9919.jpg
#   inflating: PetImages/PetImages/Dog/2694.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2694.jpg
#   inflating: PetImages/PetImages/Dog/11973.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11973.jpg
#   inflating: PetImages/PetImages/Dog/5845.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5845.jpg
#   inflating: PetImages/PetImages/Dog/4583.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4583.jpg
#   inflating: PetImages/PetImages/Dog/6394.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6394.jpg
#   inflating: PetImages/PetImages/Dog/6380.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6380.jpg
#   inflating: PetImages/PetImages/Dog/11967.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11967.jpg
#   inflating: PetImages/PetImages/Dog/5689.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5689.jpg
#   inflating: PetImages/PetImages/Dog/5851.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5851.jpg
#   inflating: PetImages/PetImages/Dog/4597.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4597.jpg
#   inflating: PetImages/PetImages/Dog/2858.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2858.jpg
#   inflating: PetImages/PetImages/Dog/2680.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2680.jpg
#   inflating: PetImages/PetImages/Dog/85.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._85.jpg
#   inflating: PetImages/PetImages/Dog/7920.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7920.jpg
#   inflating: PetImages/PetImages/Dog/1389.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1389.jpg
#   inflating: PetImages/PetImages/Dog/2870.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2870.jpg
#   inflating: PetImages/PetImages/Dog/635.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._635.jpg
#   inflating: PetImages/PetImages/Dog/7908.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7908.jpg
#   inflating: PetImages/PetImages/Dog/9925.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9925.jpg
#   inflating: PetImages/PetImages/Dog/8385.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8385.jpg
#   inflating: PetImages/PetImages/Dog/153.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._153.jpg
#   inflating: PetImages/PetImages/Dog/10489.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10489.jpg
#   inflating: PetImages/PetImages/Dog/5879.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5879.jpg
#   inflating: PetImages/PetImages/Dog/11797.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11797.jpg
#   inflating: PetImages/PetImages/Dog/11783.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11783.jpg
#   inflating: PetImages/PetImages/Dog/8391.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8391.jpg
#   inflating: PetImages/PetImages/Dog/147.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._147.jpg
#   inflating: PetImages/PetImages/Dog/621.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._621.jpg
#   inflating: PetImages/PetImages/Dog/9931.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9931.jpg
#   inflating: PetImages/PetImages/Dog/2864.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2864.jpg
#   inflating: PetImages/PetImages/Dog/2657.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2657.jpg
#   inflating: PetImages/PetImages/Dog/10310.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10310.jpg
#   inflating: PetImages/PetImages/Dog/5138.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5138.jpg
#   inflating: PetImages/PetImages/Dog/4226.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4226.jpg
#   inflating: PetImages/PetImages/Dog/3549.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3549.jpg
#   inflating: PetImages/PetImages/Dog/812.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._812.jpg
#   inflating: PetImages/PetImages/Dog/6431.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6431.jpg
#   inflating: PetImages/PetImages/Dog/52.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._52.jpg
#   inflating: PetImages/PetImages/Dog/9702.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9702.jpg
#   inflating: PetImages/PetImages/Dog/1438.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1438.jpg
#   inflating: PetImages/PetImages/Dog/6357.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6357.jpg
#   inflating: PetImages/PetImages/Dog/9064.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9064.jpg
#   inflating: PetImages/PetImages/Dog/7049.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7049.jpg
#   inflating: PetImages/PetImages/Dog/12261.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12261.jpg
#   inflating: PetImages/PetImages/Dog/11768.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11768.jpg
#   inflating: PetImages/PetImages/Dog/5886.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5886.jpg
#   inflating: PetImages/PetImages/Dog/0.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._0.jpg
#   inflating: PetImages/PetImages/Dog/4540.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4540.jpg
#   inflating: PetImages/PetImages/Dog/2131.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2131.jpg
#   inflating: PetImages/PetImages/Dog/10476.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10476.jpg
#   inflating: PetImages/PetImages/Dog/5892.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5892.jpg
#   inflating: PetImages/PetImages/Dog/4554.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4554.jpg
#   inflating: PetImages/PetImages/Dog/2125.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2125.jpg
#   inflating: PetImages/PetImages/Dog/10462.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10462.jpg
#   inflating: PetImages/PetImages/Dog/6343.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6343.jpg
#   inflating: PetImages/PetImages/Dog/9070.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9070.jpg
#   inflating: PetImages/PetImages/Dog/12275.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12275.jpg
#   inflating: PetImages/PetImages/Dog/806.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._806.jpg
#   inflating: PetImages/PetImages/Dog/8408.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8408.jpg
#   inflating: PetImages/PetImages/Dog/46.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._46.jpg
#   inflating: PetImages/PetImages/Dog/6425.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6425.jpg
#   inflating: PetImages/PetImages/Dog/9716.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9716.jpg
#   inflating: PetImages/PetImages/Dog/2643.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2643.jpg
#   inflating: PetImages/PetImages/Dog/10304.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10304.jpg
#   inflating: PetImages/PetImages/Dog/4232.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4232.jpg
#   inflating: PetImages/PetImages/Dog/8420.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8420.jpg
#   inflating: PetImages/PetImages/Dog/7713.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7713.jpg
#   inflating: PetImages/PetImages/Dog/1362.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1362.jpg
#   inflating: PetImages/PetImages/Dog/5104.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5104.jpg
#   inflating: PetImages/PetImages/Dog/11032.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11032.jpg
#   inflating: PetImages/PetImages/Dog/3575.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3575.jpg
#   inflating: PetImages/PetImages/Dog/11754.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11754.jpg
#   inflating: PetImages/PetImages/Dog/3213.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3213.jpg
#   inflating: PetImages/PetImages/Dog/5662.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5662.jpg
#   inflating: PetImages/PetImages/Dog/190.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._190.jpg
#   inflating: PetImages/PetImages/Dog/1404.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1404.jpg
#   inflating: PetImages/PetImages/Dog/9058.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._9058.jpg
#   inflating: PetImages/PetImages/Dog/8346.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8346.jpg
#   inflating: PetImages/PetImages/Dog/7075.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7075.jpg
#   inflating: PetImages/PetImages/Dog/1410.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1410.jpg
#   inflating: PetImages/PetImages/Dog/184.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._184.jpg
#   inflating: PetImages/PetImages/Dog/8352.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8352.jpg
#   inflating: PetImages/PetImages/Dog/7061.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7061.jpg
#   inflating: PetImages/PetImages/Dog/12249.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._12249.jpg
#   inflating: PetImages/PetImages/Dog/11740.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11740.jpg
#   inflating: PetImages/PetImages/Dog/3207.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3207.jpg
#   inflating: PetImages/PetImages/Dog/4568.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._4568.jpg
#   inflating: PetImages/PetImages/Dog/5676.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5676.jpg
#   inflating: PetImages/PetImages/Dog/11998.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11998.jpg
#   inflating: PetImages/PetImages/Dog/2119.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._2119.jpg
#   inflating: PetImages/PetImages/Dog/10338.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._10338.jpg
#   inflating: PetImages/PetImages/Dog/5110.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._5110.jpg
#   inflating: PetImages/PetImages/Dog/11026.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._11026.jpg
#   inflating: PetImages/PetImages/Dog/3561.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._3561.jpg
#   inflating: PetImages/PetImages/Dog/8434.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._8434.jpg
#   inflating: PetImages/PetImages/Dog/7707.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._7707.jpg
#   inflating: PetImages/PetImages/Dog/6419.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._6419.jpg
#   inflating: PetImages/PetImages/Dog/1376.jpg
#   inflating: PetImages/__MACOSX/PetImages/Dog/._1376.jpg

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
dataDir = 'PetImages/PetImages/'

# %%
dataset = datasets.ImageFolder(root=dataDir, transform=transform)

# %%
dataset_size = len(dataset)
train_size = int(0.7 * dataset_size)
val_size = int(0.15 * dataset_size)
test_size = dataset_size - train_size - val_size

# %%
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

print(f"Total samples: {dataset_size}")
print(f"Training samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Testing samples: {len(test_dataset)}")
# Out:
# Total samples: 24998
# Training samples: 17498
# Validation samples: 3749
# Testing samples: 3751

# %%
import os
from PIL import Image, UnidentifiedImageError

def verify_images(root_dir):
    removed_files = []
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            file_path = os.path.join(subdir, file)
            try:
                with Image.open(file_path) as img:
                    img.verify()
            except (UnidentifiedImageError, OSError) as e:
                print(f"Removing corrupted image: {file_path}")
                os.remove(file_path)
                removed_files.append(file_path)
    print(f"Total corrupted images removed: {len(removed_files)}")

data_dir = 'PetImages/PetImages'
verify_images(data_dir)
# Out:
# Removing corrupted image: PetImages/PetImages/.DS_Store
# Removing corrupted image: PetImages/PetImages/Dog/11702.jpg
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Removing corrupted image: PetImages/PetImages/Dog/Thumbs.db
# Removing corrupted image: PetImages/PetImages/Cat/666.jpg
# Removing corrupted image: PetImages/PetImages/Cat/Thumbs.db
# Total corrupted images removed: 5

# %% [markdown]
# 2. Choose to use a pre-defined ViT model or implement it from scratch. You can use an in-built predefined models for this part.

# %%
num_classes = 2

model = timm.create_model('vit_base_patch16_224', pretrained=True)

print("Original classification head:", model.head)

in_features = model.head.in_features
model.head = nn.Linear(in_features, num_classes)
print("Modified classification head:", model.head)

for param in model.parameters():
    param.requires_grad = False
for param in model.head.parameters():
    param.requires_grad = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Original classification head: Linear(in_features=768, out_features=1000, bias=True)
# Modified classification head: Linear(in_features=768, out_features=2, bias=True)
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=768, out_features=2, bias=True)
# )

# %% [markdown]
# 3. Train and evaluate your ViT model. Discuss your results.

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

num_epochs = 4
train_losses = []
val_losses = []
val_accuracies = []

for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0.0
    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Training", leave=False):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)
    print(f"Epoch [{epoch+1}/{num_epochs}] Training Loss: {epoch_loss:.4f}")

    # Validation
    model.eval()
    val_running_loss = 0.0
    correct_preds = 0
    total_samples = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_running_loss += loss.item() * images.size(0)

            _, predicted = torch.max(outputs, 1)
            total_samples += labels.size(0)
            correct_preds += (predicted == labels).sum().item()

    epoch_val_loss = val_running_loss / len(val_loader.dataset)
    epoch_val_acc = correct_preds / total_samples
    val_losses.append(epoch_val_loss)
    val_accuracies.append(epoch_val_acc)

    print(f"Epoch [{epoch+1}/{num_epochs}] Validation Loss: {epoch_val_loss:.4f}, Validation Accuracy: {epoch_val_acc:.4f}")
# Out:
# Epoch [1/4] Training Loss: 0.0152
# Epoch [1/4] Validation Loss: 0.0233, Validation Accuracy: 0.9933
# Epoch [2/4] Training Loss: 0.0133
# Epoch [2/4] Validation Loss: 0.0236, Validation Accuracy: 0.9936
# Epoch [3/4] Training Loss: 0.0120
# Epoch [3/4] Validation Loss: 0.0240, Validation Accuracy: 0.9936
# Epoch [4/4] Training Loss: 0.0109
# Epoch [4/4] Validation Loss: 0.0245, Validation Accuracy: 0.9931

# %%
model.eval()

test_running_loss = 0.0
correct_test = 0
total_test = 0

with torch.no_grad():
    for images, labels in test_loader:

        images, labels = images.to(device), labels.to(device)

        outputs = model(images)

        loss = criterion(outputs, labels)
        test_running_loss += loss.item() * images.size(0)

        _, predicted = torch.max(outputs, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()

test_loss = test_running_loss / len(test_loader.dataset)
test_accuracy = correct_test / total_test

print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Loss: 0.0209, Test Accuracy: 0.9931

# %%
modelSavePath = "vit_catdog_model.pth"
torch.save(model.state_dict(), modelSavePath)

print(f"Model weights saved to {modelSavePath}")
# Out:
# Model weights saved to vit_catdog_model.pth

# %% [markdown]
# The model demonstrates very strong performance across training, validation, and test sets. Over the course of four epochs, the training loss steadily decreased from 0.0152 to 0.0109, which indicates that the model is effectively learning. The validation loss remains consistently low, ranging from 0.0233 to 0.0245, while the validation accuracy hovered around 99.33% to 99.36%. These consistent metrics shows us that the model is generalizing well and not overfitting, as the gap between training and validation performance is low. The test set further confirms the stength of the model with a loss of 0.0209 and an accuracy of 99.31%, showing us that the model performs reliably on unseen data. Overall, the results indicate that the fine tuned Vision Transformer is highly effective for the binary classification task of distinguishing between cats and dogs.

# %% [markdown]
# 4. Deploy your trained ViT model. This could be a simple script or application that takes an image as input and predicts whether it's a cat or a dog.

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.25.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.9.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.8.0 (from gradio)
#   Downloading gradio_client-1.8.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.30.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.10.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.11.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.11.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.13.1)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.8.0->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.8.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-5.25.0-py3-none-any.whl (46.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 47.2 MB/s eta 0:00:00
# Downloading gradio_client-1.8.0-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 27.6 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.7 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 121.2 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.7 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading uvicorn-0.34.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.4 MB/s eta 0:00:00
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, uvicorn, tomlkit, semantic-version, ruff, python-multipart, groovy, ffmpy, aiofiles, starlette, safehttpx, gradio-client, fastapi, gradio
# Successfully installed aiofiles-24.1.0 fastapi-0.115.12 ffmpy-0.5.0 gradio-5.25.0 gradio-client-1.8.0 groovy-0.1.2 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.5 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.46.2 tomlkit-0.13.2 uvicorn-0.34.1

# %%
import gradio as gr

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

num_classes = 2
model = timm.create_model('vit_base_patch16_224', pretrained=False)
in_features = model.head.in_features
model.head = nn.Linear(in_features, num_classes)

model_save_path = "vit_catdog_model.pth"
model.load_state_dict(torch.load(model_save_path, map_location=device))
model.to(device)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

def predict(image):
    image = image.convert("RGB")

    input_tensor = transform(image).unsqueeze(0)
    input_tensor = input_tensor.to(device)

    model.eval()
    with torch.no_grad():
        outputs = model(input_tensor)
        _, predicted = torch.max(outputs, 1)

    class_names = ['Cat', 'Dog']
    prediction = class_names[predicted.item()]

    return prediction

iface = gr.Interface(
    fn=predict,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="Cat vs Dog Classifier",
    description="Upload an image and the model will predict whether it's a cat or a dog."
)

iface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b5491cf41a53dc8925.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b5491cf41a53dc8925.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# 5. Record a short video (~5 mins) demonstrating how your deployed ViT model works. The video should showcase the model taking image inputs and providing predictions. Explain the key aspects of your implementation and deployment process in the video.
#    a. Upload the video to UBbox and create a shared link
#    b. Add the link at the end of your ipynb file.

# %% [markdown]
# **Shared UBbox Video Link: https://buffalo.box.com/s/3ay8aflm5pvzattgct0r81x0mhds19is

# %% [markdown]
# <span style='color:green'>### YOUR ANSWER ###</span>

# %% [markdown]
# 6. References. Include details on all the resources used to complete this part.

# %% [markdown]
# Hugging face vit trasnformer - https://huggingface.co/docs/transformers/en/model_doc/vit
#
# Gradio -User Interface - https://www.gradio.app
